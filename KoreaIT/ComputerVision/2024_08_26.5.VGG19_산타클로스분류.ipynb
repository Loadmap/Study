# %%
import os
import glob
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, dataset, SubsetRandomSampler
from torchvision.datasets import ImageFolder
import torchvision.models as models
from PIL import Image
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

device
# Out:
# device(type='cuda')

# %%
zip_name = "/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/산타vs일반인.zip"
colab_folder = "/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/"

# %%
# !unzip -q "{zip_name}" -d "{colab_folder}"

# %%
data_root = '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4'

# %%
def display_images(image_paths, title, max_images = 4) :
    plt.figure(figsize = (12, 3))

    for i, image_path in enumerate(image_paths[: max_images]) :
        img = plt.imread(image_path)
        plt.subplot(1, max_images, i + 1)
        plt.imshow(img)
        plt.title(title)
        plt.axis('off')

    plt.show()

# %%
categories = ['Train Santa', 'Train normal',
              'Val Santa', 'Val normal',
              'Test Santa', 'Test normal']

# %%
for category in categories :
    image_paths= glob.glob(f'{data_root}/{category.lower().replace(" ", "/")}/*')

    print(image_paths)
    display_images(image_paths, category)
    print(f'{category} 총 이미지 수 : {len(image_paths)}')
# Out:
# ['/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/116.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/125.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/226.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/265.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/104.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/225.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/117.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/14.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/150.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/255.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/25.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/196.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/202.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/218.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/21.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/113.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/207.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/139.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/120.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/129.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/123.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/164.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/236.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/135.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/16.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/145.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/234.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/210.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/118.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/147.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/250.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/167.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/115.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/241.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/158.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/173.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/152.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/187.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/245.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/201.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/161.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/260.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/santa/100.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/Compu ...
# Train Santa 총 이미지 수 : 446
# ['/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/103.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/111.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/118.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/105.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/107.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/117.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/113.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/104.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/0.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/109.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/1.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/110.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/100.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/114.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/115.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/116.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/188.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/234.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/15.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/145.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/138.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/169.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/17.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/14.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/170.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/135.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/161.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/265.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/187.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/292.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/164.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/224.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/250.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/272.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/245.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/218.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/255.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/281.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/121.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/train/normal/24.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/Compu ...
# Train normal 총 이미지 수 : 449
# ['/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/395.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/382.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/407.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/365.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/397.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/347.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/394.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/352.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/372.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/401.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/402.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/339.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/398.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/388.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/363.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/342.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/300.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/405.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/366.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/356.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/302.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/375.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/364.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/351.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/360.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/389.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/393.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/357.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/330.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/310.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/331.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/324.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/312.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/376.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/314.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/344.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/391.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/404.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/325.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/323.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/301.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/309.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/408.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/santa/386.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데 ...
# Val Santa 총 이미지 수 : 133
# ['/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/398.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/386.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/375.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/365.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/312.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/339.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/385.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/391.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/405.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/330.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/366.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/363.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/301.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/335.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/388.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/393.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/370.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/324.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/404.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/402.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/357.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/389.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/401.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/309.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/302.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/352.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/300.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/360.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/344.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/347.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/325.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/314.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/382.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/372.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/310.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/321.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/364.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/356.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/381.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/397.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/val/normal/323.not-a-santa.jpg', '/content/drive/MyDriv ...
# Val normal 총 이미지 수 : 134
# ['/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/564.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/573.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/553.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/557.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/562.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/568.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/555.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/566.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/554.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/563.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/569.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/558.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/570.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/583.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/587.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/603.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/608.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/590.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/598.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/584.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/601.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/604.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/595.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/607.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/580.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/574.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/597.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/585.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/611.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/609.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/581.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/602.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/578.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/582.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/579.Santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/santa/586.Santa.jpg']
# Test Santa 총 이미지 수 : 36
# ['/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/570.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/603.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/565.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/599.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/584.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/580.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/590.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/586.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/605.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/588.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/575.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/589.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/602.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/610.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/552.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/587.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/556.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/582.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/601.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/609.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/583.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/568.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/611.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/557.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/567.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/604.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/564.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/581.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/576.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/554.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/561.not-a-santa.jpg', '/content/drive/MyDrive/Korea it 아카데미/ComputerVision/data/4/test/normal/571.not-a-santa.jpg']
# Test normal 총 이미지 수 : 32

# %%
plt.figure(figsize = (10, 8))
plt.bar(categories, [len(glob.glob(f'{data_root}/{category.lower().replace(" ", "/")}/*'))
    for category in categories], color = ['blue', 'orange', 'green', 'red', 'pink', 'purple'])

plt.title('Number of Images per Category')
plt.xlabel('Category')
plt.ylabel('Number of Images')
plt.xticks(rotation = 45)

plt.show()

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    transforms.Normalize(mean = [0.485, 0.458, 0.406], std = [0.229, 0.224, 0.225])
])

# %%
train_dataset = ImageFolder(f'{data_root}/train', transform = transform)
val_dataset = ImageFolder(f'{data_root}/val', transform = transform)

train_loader = DataLoader(train_dataset, batch_size = 16, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = 16, shuffle = False)

# %%
class VGG19(nn.Module) :

    def __init__(self, num_classes = 1000) :
        super(VGG19, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            # 메모리 절약, 입력 텐서의 원본 데이터가 변경
            nn.ReLU(inplace = True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.Conv2d(512, 512, kernel_size=3, padding=1),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size=2, stride=2)
    )

        self.classifier = nn.Sequential(
            nn.Linear(512 * 7 * 7, 4096),
            nn.ReLU(inplace = True),
            nn.Dropout(),

            nn.Linear(4096, 4096),
            nn.ReLU(inplace = True),
            nn.Dropout(),

            nn.Linear(4096, num_classes)  # Output layer for 1000 classes
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)  # Flatten the tensor for the fully connected layers
        x = self.classifier(x)

        return x

# %%
# 사전 학습된 vgg19 모델 불러오기

pretrained_vgg19 = models.vgg19(pretrained = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:10<00:00, 57.3MB/s]

# %%
model = VGG19(num_classes=1000)

# %%
pretrained_keys = set(pretrained_vgg19.features.state_dict().keys())

# %%
# state_dict 키와 모델의 파라미터 이름이 일치하지 않으면 오류가 발생
# strict = False 설정하면 일부 파라미터가 다르더라도 일치하는 부분만 로드 나머지는 무시

result = model.features.load_state_dict(pretrained_vgg19.features.state_dict(), strict = False)

# %%
# 복사 후 커스텀 모델의 features 부분에서 가중치 추출

custom_keys = set(model.features.state_dict().keys())

# %%
# 커스텀 모델과 사전 학습된 모델 모두에 존재하는 가중치

successfully_copied_keys = pretrained_keys.intersection(custom_keys)

# %%
# 커스텀 모델에는 있으나 사전 학습된 모델에는 없는 가중치

missing_keys = custom_keys - pretrained_keys

# %%
# 사전 학습된 모델에는 있지만 커스텀 모델에 없는 가중치

unexpected_keys = pretrained_keys - custom_keys

# %%
print('successfully_copied_keys : ', successfully_copied_keys)
print('missing_keys : ', missing_keys)
print('unexpected_keys : ', unexpected_keys)
# Out:
# successfully_copied_keys :  {'21.weight', '34.bias', '25.weight', '0.bias', '32.weight', '23.weight', '30.bias', '16.bias', '28.weight', '10.bias', '7.weight', '30.weight', '23.bias', '16.weight', '2.bias', '12.bias', '12.weight', '34.weight', '28.bias', '7.bias', '19.bias', '25.bias', '0.weight', '14.bias', '32.bias', '2.weight', '5.weight', '10.weight', '14.weight', '5.bias', '19.weight', '21.bias'}
# missing_keys :  set()
# unexpected_keys :  set()

# %%
for param in model.features.parameters() :
    param.requires_gard = False

# %%
model.classifier[6] = nn.Linear(4096, 1)

for param in model.classifier.parameters() :
    param.requires_grad = True

# %%
model = model.to(device)
model
# Out:
# VGG19(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1, bias=True)
#   )
# )

# %%
loss_func = nn.BCEWithLogitsLoss()

# %%
def validate_model(model, val_loader, loss_func) :
    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad() :

        for inputs, labels in val_loader :
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.float().unsqueeze(1)
            outputs = model(inputs)
            val_loss += loss_func(outputs, labels).item()
            predicted = torch.sigmoid(outputs) > 0.5
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_loss /= len(val_loader)
    val_accuracy = 100 * correct / total

    return val_loss, val_accuracy

# %%
def train_model(optim_name, model, train_loader, val_loader, loss_func, num_epochs=10):

    if optim_name == 'SGD':
        optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

    elif optim_name == 'Adam':
        optimizer = optim.Adam(model.parameters(), lr=0.001, betas=(0.9, 0.999))

    elif optim_name == 'RAdam':
        optimizer = optim.RAdam(model.parameters(), lr=0.001, betas=(0.9, 0.999))

    else:

        raise ValueError(f'Unsupported optimizer: {optim_name}')

    train_losses = []
    val_losses = []
    val_accuracies = []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0

        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            labels = labels.float().unsqueeze(1)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = loss_func(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        train_loss = running_loss / len(train_loader)
        train_losses.append(train_loss)

        val_loss, val_accuracy = validate_model(model, val_loader, loss_func)
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        print(f'[{optim_name}] Epoch {epoch + 1}, Train Loss: {train_loss:.6f}, Val Loss: {val_loss:.6f}, Val Accuracy: {val_accuracy:.2f}%')

    return train_losses, val_losses, val_accuracies

# %%
train_losses_Adam, val_losses_Adam, val_accuracies_Adam = train_model(
    'Adam', model, train_loader, val_loader, loss_func
)
# Out:
# [Adam] Epoch 1, Train Loss: 1.228998, Val Loss: 0.647990, Val Accuracy: 50.19%
# [Adam] Epoch 2, Train Loss: 0.721415, Val Loss: 0.693040, Val Accuracy: 49.81%
# [Adam] Epoch 3, Train Loss: 0.693404, Val Loss: 1.043519, Val Accuracy: 49.81%
# [Adam] Epoch 4, Train Loss: 0.693782, Val Loss: 0.693237, Val Accuracy: 50.19%
# [Adam] Epoch 5, Train Loss: 0.693499, Val Loss: 0.693235, Val Accuracy: 50.19%
# [Adam] Epoch 6, Train Loss: 0.693274, Val Loss: 0.693194, Val Accuracy: 50.19%
# [Adam] Epoch 7, Train Loss: 0.693393, Val Loss: 0.693164, Val Accuracy: 50.19%
# [Adam] Epoch 8, Train Loss: 0.693431, Val Loss: 0.693095, Val Accuracy: 49.81%
# [Adam] Epoch 9, Train Loss: 0.693219, Val Loss: 0.693280, Val Accuracy: 50.19%
# [Adam] Epoch 10, Train Loss: 0.693408, Val Loss: 0.693307, Val Accuracy: 50.19%

# %%
# 학습 손실과 검증 정확도 그래프 그리기
plt.figure(figsize=(15, 10))
# 학습 손실 그래프
plt.subplot(3, 1, 1)  # 3행 1열의 첫 번째 위치
plt.plot(train_losses_Adam, label='Adam')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training Loss Over Epochs')
plt.legend()
# plt.ylim(0, 0.2)
# 검증 손실 그래프
plt.subplot(3, 1, 2)  # 3행 1열의 두 번째 위치
plt.plot(val_losses_Adam, label='Adam')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss Over Epochs')
plt.legend()
# plt.ylim(0, 1.5)
# 검증 정확도 그래프
plt.subplot(3, 1, 3)  # 3행 1열의 세 번째 위치
plt.plot(val_accuracies_Adam, label='Adam', color='green')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Validation Accuracy Over Epochs')
plt.legend()
# plt.ylim(80, 100)
plt.tight_layout()
plt.show()

# %%
def load_and_transfor_img(image_path, transform) :
    image = Image.open(image_path).convert('RGB')

    return transform(image).unsqueeze(0).to(device)

# %%
class_folders = {
    'santa' : f'{data_root}/test/santa',
    'normal' : f'{data_root}/test/normal'
}

plt.figure(figsize = (20, 8))

counter = 1

for class_name, folder_path in class_folders.items() :
    image_paths = glob.glob(os.path.join(folder_path, '*'))
    selected_paths = image_paths[: 5]

    for image_path in selected_paths :
        image = load_and_transfor_img(image_path, transform)

        model.eval()

        with torch.no_grad() :
            outputs = model(image)
            probs = torch.sigmoid(outputs)
        prediction = 'santa' if probs > 0.5 else 'normal'

        plt.subplot(2, 5, counter)
        plt.imshow(Image.open(image_path))
        plt.title(f'True : {class_name}, Pred : {prediction}')
        plt.axis('off')

        counter += 1
plt.tight_layout()
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
