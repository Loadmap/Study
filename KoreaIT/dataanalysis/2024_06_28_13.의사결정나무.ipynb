# %% [markdown]
# # **1. bike 데이터 셋**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bike_df = pd.read_csv('/content/drive/MyDrive/Korea it 아카데미/data analysis/data/bike.csv')

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33379 entries, 0 to 33378
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      33379 non-null  object
#  1   count         33379 non-null  int64
#  2   holiday       33379 non-null  int64
#  3   workingday    33379 non-null  int64
#  4   temp          33379 non-null  float64
#  5   feels_like    33379 non-null  float64
#  6   temp_min      33379 non-null  float64
#  7   temp_max      33379 non-null  float64
#  8   pressure      33379 non-null  int64
#  9   humidity      33379 non-null  int64
#  10  wind_speed    33379 non-null  float64
#  11  wind_deg      33379 non-null  int64
#  12  rain_1h       6771 non-null   float64
#  13  snow_1h       326 non-null    float64
#  14  clouds_all    33379 non-null  int64
#  15  weather_main  33379 non-null  object
# dtypes: float64(7), int64(7), object(2)
# memory usage: 4.1+ MB

# %% [markdown]
# * datetime: 날짜
# * count: 대여 개수
# * holiday: 휴일
# * workingday: 근무일
# * temp: 기온
# * feels_like: 체감온도
# * temp_min: 최저온도
# * temp_max: 최고온도
# * pressure: 기압
# * humidity: 습도
# * wind_speed: 풍속
# * wind_deg: 풍향
# * rain_1h: 1시간당 내리는 비의 양
# * snow_1h: 1시간당 내리는 눈의 양
# * clouds_all: 구름의 양
# * weather_main: 날씨

# %%
bike_df.describe()
# Out:
#               count       holiday    workingday          temp    feels_like  \
# count  33379.000000  33379.000000  33379.000000  33379.000000  33379.000000
# mean     333.139788      0.030618      0.681327     15.213087     14.994843
# std      336.519514      0.172283      0.465969      9.908964     11.176487
# min        0.000000      0.000000      0.000000    -12.790000    -18.910000
# 25%       59.000000      0.000000      0.000000      6.860000      5.880000
# 50%      236.000000      0.000000      1.000000     15.650000     15.020000
# 75%      495.000000      0.000000      1.000000     23.800000     24.140000
# max     2038.000000      1.000000      1.000000     36.710000     43.710000
#
#            temp_min      temp_max      pressure      humidity    wind_speed  \
# count  33379.000000  33379.000000  33379.000000  33379.000000  33379.000000
# mean      13.532648     16.105542   1017.071602     67.818628      1.829340
# ...

# %%
sns.displot(bike_df['count'])

# %%
sns.boxplot(y = bike_df['count'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.scatterplot(data = bike_df, x = 'feels_like', y = 'count', alpha = 0.3)
# Out:
# <Axes: xlabel='feels_like', ylabel='count'>

# %%
sns.scatterplot(data = bike_df, x = 'pressure', y = 'count', alpha = 0.3)
# Out:
# <Axes: xlabel='pressure', ylabel='count'>

# %%
sns.scatterplot(data = bike_df, x = 'wind_speed', y = 'count', alpha = 0.3)
# Out:
# <Axes: xlabel='wind_speed', ylabel='count'>

# %%
sns.scatterplot(data = bike_df, x = 'wind_deg', y = 'count', alpha = 0.3)
# Out:
# <Axes: xlabel='wind_deg', ylabel='count'>

# %%
bike_df.isna().sum()
# Out:
# datetime            0
# count               0
# holiday             0
# workingday          0
# temp                0
# feels_like          0
# temp_min            0
# temp_max            0
# pressure            0
# humidity            0
# wind_speed          0
# wind_deg            0
# rain_1h         26608
# snow_1h         33053
# clouds_all          0
# weather_main        0
# dtype: int64

# %%
bike_df = bike_df.fillna(0)

bike_df.isna().sum()
# Out:
# datetime        0
# count           0
# holiday         0
# workingday      0
# temp            0
# feels_like      0
# temp_min        0
# temp_max        0
# pressure        0
# humidity        0
# wind_speed      0
# wind_deg        0
# rain_1h         0
# snow_1h         0
# clouds_all      0
# weather_main    0
# dtype: int64

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33379 entries, 0 to 33378
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      33379 non-null  object
#  1   count         33379 non-null  int64
#  2   holiday       33379 non-null  int64
#  3   workingday    33379 non-null  int64
#  4   temp          33379 non-null  float64
#  5   feels_like    33379 non-null  float64
#  6   temp_min      33379 non-null  float64
#  7   temp_max      33379 non-null  float64
#  8   pressure      33379 non-null  int64
#  9   humidity      33379 non-null  int64
#  10  wind_speed    33379 non-null  float64
#  11  wind_deg      33379 non-null  int64
#  12  rain_1h       33379 non-null  float64
#  13  snow_1h       33379 non-null  float64
#  14  clouds_all    33379 non-null  int64
#  15  weather_main  33379 non-null  object
# dtypes: float64(7), int64(7), object(2)
# memory usage: 4.1+ MB

# %%
bike_df['datetime'] = pd.to_datetime(bike_df['datetime'])

bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33379 entries, 0 to 33378
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datetime      33379 non-null  datetime64[ns]
#  1   count         33379 non-null  int64
#  2   holiday       33379 non-null  int64
#  3   workingday    33379 non-null  int64
#  4   temp          33379 non-null  float64
#  5   feels_like    33379 non-null  float64
#  6   temp_min      33379 non-null  float64
#  7   temp_max      33379 non-null  float64
#  8   pressure      33379 non-null  int64
#  9   humidity      33379 non-null  int64
#  10  wind_speed    33379 non-null  float64
#  11  wind_deg      33379 non-null  int64
#  12  rain_1h       33379 non-null  float64
#  13  snow_1h       33379 non-null  float64
#  14  clouds_all    33379 non-null  int64
#  15  weather_main  33379 non-null  object
# dtypes: datetime64[ns](1), float64(7), int64(7), object(1)
# memory usage: 4.1+ MB

# %%
bike_df.head() # 2018-01-01 00:00:00
# Out:
#              datetime  count  holiday  workingday  temp  feels_like  temp_min  \
# 0 2018-01-01 00:00:00     34        1           0 -7.17      -12.73     -8.56
# 1 2018-01-01 01:00:00     49        1           0 -7.35      -13.81     -9.03
# 2 2018-01-01 02:00:00     37        1           0 -7.88      -14.05     -9.03
# 3 2018-01-01 03:00:00      9        1           0 -8.10      -14.32     -9.36
# 4 2018-01-01 04:00:00     12        1           0 -8.19      -14.43     -9.46
#
#    temp_max  pressure  humidity  wind_speed  wind_deg  rain_1h  snow_1h  \
# 0     -7.09      1030        53         3.6       310      0.0      0.0
# 1     -7.15      1030        49         4.6       310      0.0      0.0
# 2     -7.69      1031        52         4.1       310      0.0      0.0
# 3     -7.89      1031        49         4.1       310      0.0      0.0
# 4     -8.09      1031        49         4.1       330      0.0      0.0
#
#    clouds_all weather_main
# 0          20       Clouds
# ...

# %%
bike_df['year'] = bike_df['datetime'].dt.year
bike_df['month'] = bike_df['datetime'].dt.month
bike_df['hour'] = bike_df['datetime'].dt.hour

bike_df.head()
# Out:
#              datetime  count  holiday  workingday  temp  feels_like  temp_min  \
# 0 2018-01-01 00:00:00     34        1           0 -7.17      -12.73     -8.56
# 1 2018-01-01 01:00:00     49        1           0 -7.35      -13.81     -9.03
# 2 2018-01-01 02:00:00     37        1           0 -7.88      -14.05     -9.03
# 3 2018-01-01 03:00:00      9        1           0 -8.10      -14.32     -9.36
# 4 2018-01-01 04:00:00     12        1           0 -8.19      -14.43     -9.46
#
#    temp_max  pressure  humidity  wind_speed  wind_deg  rain_1h  snow_1h  \
# 0     -7.09      1030        53         3.6       310      0.0      0.0
# 1     -7.15      1030        49         4.6       310      0.0      0.0
# 2     -7.69      1031        52         4.1       310      0.0      0.0
# 3     -7.89      1031        49         4.1       310      0.0      0.0
# 4     -8.09      1031        49         4.1       330      0.0      0.0
#
#    clouds_all weather_main  year  month  hour
# ...

# %%
bike_df['date'] = bike_df['datetime'].dt.date

bike_df.head()
# Out:
#              datetime  count  holiday  workingday  temp  feels_like  temp_min  \
# 0 2018-01-01 00:00:00     34        1           0 -7.17      -12.73     -8.56
# 1 2018-01-01 01:00:00     49        1           0 -7.35      -13.81     -9.03
# 2 2018-01-01 02:00:00     37        1           0 -7.88      -14.05     -9.03
# 3 2018-01-01 03:00:00      9        1           0 -8.10      -14.32     -9.36
# 4 2018-01-01 04:00:00     12        1           0 -8.19      -14.43     -9.46
#
#    temp_max  pressure  humidity  wind_speed  wind_deg  rain_1h  snow_1h  \
# 0     -7.09      1030        53         3.6       310      0.0      0.0
# 1     -7.15      1030        49         4.6       310      0.0      0.0
# 2     -7.69      1031        52         4.1       310      0.0      0.0
# 3     -7.89      1031        49         4.1       310      0.0      0.0
# 4     -8.09      1031        49         4.1       330      0.0      0.0
#
#    clouds_all weather_main  year  month  hour        date
# ...

# %%
plt.figure(figsize = (14, 4))

sns.lineplot(data = bike_df, x = 'date', y = 'count')
plt.xticks(rotation = 45)

plt.show()

# %%
bike_df[bike_df['year'] == 2019].groupby('month')['count'].mean()
# Out:
# month
# 1     193.368862
# 2     221.857718
# 3     326.564456
# 4     482.931694
# 5     438.027848
# 6     478.480053
# 7     472.745785
# 8     481.267366
# 9     500.862069
# 10    446.279070
# 11    307.295393
# 12    213.148886
# Name: count, dtype: float64

# %%
bike_df[bike_df['year'] == 2020].groupby('month')['count'].mean() # 4월 데이터가 없음
# Out:
# month
# 1     260.445997
# 2     255.894320
# 3     217.135241
# 5     196.581064
# 6     290.900937
# 7     299.811688
# 8     331.528809
# 9     338.876478
# 10    293.640777
# 11    240.507324
# 12    138.993540
# Name: count, dtype: float64

# %%
# covid
# 2020-04-01 이전 : precovid
# 2020-04-01 이후 ~ 2021-04-01 이전 : covid
# 2021-04-01 이후 : postcovid

def covid(date) :

    if str(date) < '2020-04-01' :

        return 'precovid'

    elif str(date) < '2021-04-01' :

        return 'covid'

    else :

        return 'postcovid'

# %%
bike_df['date'].apply(covid).head()
# Out:
# 0    precovid
# 1    precovid
# 2    precovid
# 3    precovid
# 4    precovid
# Name: date, dtype: object

# %%
bike_df['covid'] = bike_df['date'].apply(
    lambda date : 'precovid' if str(date) < '2020-04-01'
                            else 'covid' if str(date) < '2021-04-01'
                            else 'postcovid'
)

# %%
bike_df.head()
# Out:
#              datetime  count  holiday  workingday  temp  feels_like  temp_min  \
# 0 2018-01-01 00:00:00     34        1           0 -7.17      -12.73     -8.56
# 1 2018-01-01 01:00:00     49        1           0 -7.35      -13.81     -9.03
# 2 2018-01-01 02:00:00     37        1           0 -7.88      -14.05     -9.03
# 3 2018-01-01 03:00:00      9        1           0 -8.10      -14.32     -9.36
# 4 2018-01-01 04:00:00     12        1           0 -8.19      -14.43     -9.46
#
#    temp_max  pressure  humidity  ...  wind_deg  rain_1h  snow_1h  clouds_all  \
# 0     -7.09      1030        53  ...       310      0.0      0.0          20
# 1     -7.15      1030        49  ...       310      0.0      0.0           1
# 2     -7.69      1031        52  ...       310      0.0      0.0           1
# 3     -7.89      1031        49  ...       310      0.0      0.0           1
# 4     -8.09      1031        49  ...       330      0.0      0.0           1
#
# ...

# %%
# season
# 12월 ~ 2월 : winter
# 3월 ~ 5월 : spring
# 6월 ~ 8월 : summer
# 9월 ~ 11월 : fall

# bike_df['season'] = bike_df['month'].apply(
#     lambda month : 'spring' if month >= 3 and month < 6
#                             else 'summer' if month >= 6 and month < 9
#                             else 'fall' if month >= 9 and month < 12
#                             else 'winter'
# )

bike_df['season'] = bike_df['month'].apply(
    lambda month : 'winter' if month ==12
                            else 'fall' if month >= 9
                            else 'summer' if month >= 6
                            else 'spring' if month >= 3
                            else 'winter'
)

bike_df.head()
# Out:
#              datetime  count  holiday  workingday  temp  feels_like  temp_min  \
# 0 2018-01-01 00:00:00     34        1           0 -7.17      -12.73     -8.56
# 1 2018-01-01 01:00:00     49        1           0 -7.35      -13.81     -9.03
# 2 2018-01-01 02:00:00     37        1           0 -7.88      -14.05     -9.03
# 3 2018-01-01 03:00:00      9        1           0 -8.10      -14.32     -9.36
# 4 2018-01-01 04:00:00     12        1           0 -8.19      -14.43     -9.46
#
#    temp_max  pressure  humidity  ...  rain_1h  snow_1h  clouds_all  \
# 0     -7.09      1030        53  ...      0.0      0.0          20
# 1     -7.15      1030        49  ...      0.0      0.0           1
# 2     -7.69      1031        52  ...      0.0      0.0           1
# 3     -7.89      1031        49  ...      0.0      0.0           1
# 4     -8.09      1031        49  ...      0.0      0.0           1
#
#    weather_main  year month  hour        date     covid  season
# ...

# %%
bike_df[bike_df['month'] == 12]['season']
# Out:
# 8582     winter
# 8583     winter
# 8584     winter
# 8585     winter
# 8586     winter
#           ...
# 27206    winter
# 27207    winter
# 27208    winter
# 27209    winter
# 27210    winter
# Name: season, Length: 2487, dtype: object

# %%
# day_night
# 21시 이후 ~ : night
# 19시 이후 ~ : late evening
# 17시 이후 ~ : early evening
# 15시 이후 ~ : late afternoon
# 13시 이후 ~ : early afternoon
# 11시 이후 ~ : late morning
# 6시 이후 ~ : early morning

bike_df['day_night'] = bike_df['hour'].apply(
    lambda hour : 'night' if hour >= 21
                            else 'late evening' if hour >= 19
                            else 'early evening' if hour >= 17
                            else 'late afternoon' if hour >= 15
                            else 'early afternoon' if hour >= 13
                            else 'late morning' if hour >= 11
                            else 'early morning' if hour >= 6
                            else 'night'

)

# %%
bike_df.head()
# Out:
#              datetime  count  holiday  workingday  temp  feels_like  temp_min  \
# 0 2018-01-01 00:00:00     34        1           0 -7.17      -12.73     -8.56
# 1 2018-01-01 01:00:00     49        1           0 -7.35      -13.81     -9.03
# 2 2018-01-01 02:00:00     37        1           0 -7.88      -14.05     -9.03
# 3 2018-01-01 03:00:00      9        1           0 -8.10      -14.32     -9.36
# 4 2018-01-01 04:00:00     12        1           0 -8.19      -14.43     -9.46
#
#    temp_max  pressure  humidity  ...  snow_1h  clouds_all  weather_main  year  \
# 0     -7.09      1030        53  ...      0.0          20        Clouds  2018
# 1     -7.15      1030        49  ...      0.0           1         Clear  2018
# 2     -7.69      1031        52  ...      0.0           1         Clear  2018
# 3     -7.89      1031        49  ...      0.0           1         Clear  2018
# 4     -8.09      1031        49  ...      0.0           1         Clear  2018
#
# ...

# %%
bike_df.drop(['datetime', 'month', 'date', 'hour'], axis = 1, inplace = True)

# %%
bike_df.head()
# Out:
#    count  holiday  workingday  temp  feels_like  temp_min  temp_max  pressure  \
# 0     34        1           0 -7.17      -12.73     -8.56     -7.09      1030
# 1     49        1           0 -7.35      -13.81     -9.03     -7.15      1030
# 2     37        1           0 -7.88      -14.05     -9.03     -7.69      1031
# 3      9        1           0 -8.10      -14.32     -9.36     -7.89      1031
# 4     12        1           0 -8.19      -14.43     -9.46     -8.09      1031
#
#    humidity  wind_speed  wind_deg  rain_1h  snow_1h  clouds_all weather_main  \
# 0        53         3.6       310      0.0      0.0          20       Clouds
# 1        49         4.6       310      0.0      0.0           1        Clear
# 2        52         4.1       310      0.0      0.0           1        Clear
# 3        49         4.1       310      0.0      0.0           1        Clear
# 4        49         4.1       330      0.0      0.0           1        Clear
#
# ...

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33379 entries, 0 to 33378
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   count         33379 non-null  int64
#  1   holiday       33379 non-null  int64
#  2   workingday    33379 non-null  int64
#  3   temp          33379 non-null  float64
#  4   feels_like    33379 non-null  float64
#  5   temp_min      33379 non-null  float64
#  6   temp_max      33379 non-null  float64
#  7   pressure      33379 non-null  int64
#  8   humidity      33379 non-null  int64
#  9   wind_speed    33379 non-null  float64
#  10  wind_deg      33379 non-null  int64
#  11  rain_1h       33379 non-null  float64
#  12  snow_1h       33379 non-null  float64
#  13  clouds_all    33379 non-null  int64
#  14  weather_main  33379 non-null  object
#  15  year          33379 non-null  int32
#  16  covid         33379 non-null  object
#  17  season        33379 non-null  object
# ...

# %%
for i in ['weather_main', 'covid', 'season', 'day_night'] :
    print(i, bike_df[i].nunique())
# Out:
# weather_main 11
# covid 3
# season 4
# day_night 7

# %%
bike_df['weather_main'].unique()
# Out:
# array(['Clouds', 'Clear', 'Snow', 'Mist', 'Rain', 'Fog', 'Drizzle',
#        'Haze', 'Thunderstorm', 'Smoke', 'Squall'], dtype=object)

# %%
bike_df = pd.get_dummies(bike_df, columns = ['weather_main', 'covid', 'season', 'day_night'])

bike_df.head()
# Out:
#    count  holiday  workingday  temp  feels_like  temp_min  temp_max  pressure  \
# 0     34        1           0 -7.17      -12.73     -8.56     -7.09      1030
# 1     49        1           0 -7.35      -13.81     -9.03     -7.15      1030
# 2     37        1           0 -7.88      -14.05     -9.03     -7.69      1031
# 3      9        1           0 -8.10      -14.32     -9.36     -7.89      1031
# 4     12        1           0 -8.19      -14.43     -9.46     -8.09      1031
#
#    humidity  wind_speed  ...  season_spring  season_summer  season_winter  \
# 0        53         3.6  ...          False          False           True
# 1        49         4.6  ...          False          False           True
# 2        52         4.1  ...          False          False           True
# 3        49         4.1  ...          False          False           True
# 4        49         4.1  ...          False          False           True
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(bike_df.drop('count', axis = 1),
                                                    bike_df['count'],
                                                    test_size = 0.2,
                                                    random_state = 2024)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((26703, 39), (6676, 39), (26703,), (6676,))

# %% [markdown]
# # **2. 의사 결정 나무(Decision Tree)**
#
# * 데이터를 분석하고 패턴을 파악하여 결정규칙을 나무구조로 나타낸 기계 학습 알고리즘
# * 간단하고 강력한 모델 중 하나로 분류와 회귀 문제에 모두 사용
# * 엔트로피 : 데이터의 불확실성을 측정, 특정 속성으로 데이터를 나누었을때 엔트로피가 얼마나 감소하는지를 계산하여 정보를 얻음, 정보 이득이 높은 속성을 선택하여 데이터를 나누게 됨
# * 지니계수 : 데이터의 분순도를 측정하는 또 다른 방법 임의로 선택된 두개의 요소가 서로 다른 클래스에 속할 확률을 나타냄, 지니 불순도가 낮을 수록 데이터가 잘 분리된 것
# * 의사 결정 나무는 오버 피팅이 매우 잘 일어남
#     * 오버피팅(과적합) : 학습 데이터에서는 정확하나 테스트 데이터에서는 성과가 나쁜 현상을 말함
#     * 오버피팅을 방지하는 방법
#         * 사전 가지치기 : 나무가 다 자라기 전에 알고리즘을 멈추는 방법
#         * 사후 가지치기 : 나무를 끝까지 다 돌린후 밑에서부터 가지를 쳐나가는 방법

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(random_state = 2024)

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=2024)

# %%
pred1 = dtr.predict(X_test)

# %%
sns.scatterplot(x = y_test, y = pred1)
# Out:
# <Axes: xlabel='count'>

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, pred1, squared = False)
# Out:
# 210.74186203651976

# %% [markdown]
# # **3.선형회귀 vs 의사 결정 나무**

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred2 = lr.predict(X_test)

# %%
sns.scatterplot(x = y_test, y = pred2)
# Out:
# <Axes: xlabel='count'>

# %%
mean_squared_error(y_test, pred2, squared = False)
# Out:
# 221.1987722244733

# %%
# 의사 결정 나무 : 210.74186203651976
# 선형 회귀 : 221.1987722244733

210.74186203651976 - 221.1987722244733
# Out:
# -10.456910187953525

# %%
# 하이퍼 파라미터 적용

dtr = DecisionTreeRegressor(random_state = 2024, max_depth = 50, min_samples_leaf = 30)

# %%
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=50, min_samples_leaf=30, random_state=2024)

# %%
pred3 = dtr.predict(X_test)

# %%
mean_squared_error(y_test, pred3, squared = False)
# Out:
# 181.29247853838177

# %%
# 의사 결정 나무 : 210.74186203651976
# 선형 회귀 : 221.1987722244733
# 의사 결정 나무(하이퍼 파라미터 튜닝) : 181.29247853838177

181.29247853838177 - 210.74186203651976
# Out:
# -29.44938349813799

# %%
sns.scatterplot(x = y_test, y = pred3)
# Out:
# <Axes: xlabel='count'>

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize = (24, 12))
plot_tree(dtr, max_depth = 5, fontsize = 10, feature_names = X_train.columns)

plt.show()
