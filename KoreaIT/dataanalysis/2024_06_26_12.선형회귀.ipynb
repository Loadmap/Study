# %% [markdown]
# # **1. Rent 데이터 셋**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
rent_df = pd.read_csv('/content/drive/MyDrive/Korea it 아카데미/data analysis/data/rent.csv')

rent_df.head()
# Out:
#     Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0  2022-05-18  2.0  10000  1100.0  Ground out of 2   Super Area
# 1  2022-05-13  2.0  20000   800.0       1 out of 3   Super Area
# 2  2022-05-16  2.0  17000  1000.0       1 out of 3   Super Area
# 3  2022-07-04  NaN  10000   800.0       1 out of 2   Super Area
# 4  2022-05-09  2.0   7500   850.0       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# ...

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4743 non-null   float64
#  2   Rent               4746 non-null   int64
#  3   Size               4741 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 445.1+ KB

# %% [markdown]
# * Posted On: 매물 등록 날짜
# * BHK: 베드, 홀, 키친의 개수
# * Rent: 렌트비
# * Size: 집 크기
# * Floor: 총 층수 중 몇층
# * Area Type: 공용공간을 포함하는지, 집의 면적만 포함하는지
# * Area Locality: 지역
# * City: 도시
# * Furnishing Status: 풀옵션 여부
# * Tenant Preferred: 선호하는 가족형태
# * Bathroom: 화장실 개수
# * Point of Contact: 연락할 곳

# %%
rent_df.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4743.000000  4.746000e+03  4741.000000  4746.000000
# mean      2.083913  3.499345e+04   967.477536     1.965866
# std       0.832516  7.810641e+04   634.532781     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
round(rent_df.describe(), 2)
# Out:
#            BHK        Rent     Size  Bathroom
# count  4743.00     4746.00  4741.00   4746.00
# mean      2.08    34993.45   967.48      1.97
# std       0.83    78106.41   634.53      0.88
# min       1.00     1200.00    10.00      1.00
# 25%       2.00    10000.00   550.00      1.00
# 50%       2.00    16000.00   850.00      2.00
# 75%       3.00    33000.00  1200.00      2.00
# max       6.00  3500000.00  8000.00     10.00

# %%
sns.displot(rent_df['BHK'])

# %%
sns.displot(rent_df['Rent'])

# %%
rent_df['Rent'].sort_values().head()
# Out:
# 4076    1200
# 285     1500
# 471     1800
# 2475    2000
# 146     2200
# Name: Rent, dtype: int64

# %%
sns.boxplot(rent_df['Rent']) # 1837 데이터는 이상치라고 예상됨
# Out:
# <Axes: ylabel='Rent'>

# %%
rent_df.isna().sum()
# Out:
# Posted On            0
# BHK                  3
# Rent                 0
# Size                 5
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
rent_df.isna().mean()
# Out:
# Posted On            0.000000
# BHK                  0.000632
# Rent                 0.000000
# Size                 0.001054
# Floor                0.000000
# Area Type            0.000000
# Area Locality        0.000000
# City                 0.000000
# Furnishing Status    0.000000
# Tenant Preferred     0.000000
# Bathroom             0.000000
# Point of Contact     0.000000
# dtype: float64

# %%
rent_df.dropna(subset = ['BHK']).head()# BHK에 nan이 있는 행 삭제
# Out:
#     Posted On  BHK   Rent    Size            Floor    Area Type  \
# 0  2022-05-18  2.0  10000  1100.0  Ground out of 2   Super Area
# 1  2022-05-13  2.0  20000   800.0       1 out of 3   Super Area
# 2  2022-05-16  2.0  17000  1000.0       1 out of 3   Super Area
# 4  2022-05-09  2.0   7500   850.0       1 out of 2  Carpet Area
# 5  2022-04-29  2.0   7000   600.0  Ground out of 1   Super Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
# 5               Thakurpukur  Kolkata       Unfurnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# ...

# %%
na_index = rent_df[rent_df['Size'].isna()].index

na_index
# Out:
# Index([425, 430, 4703, 4731, 4732], dtype='int64')

# %%
rent_df['Size'].fillna(rent_df['Size'].median()).loc[na_index]
# Out:
# 425     850.0
# 430     850.0
# 4703    850.0
# 4731    850.0
# 4732    850.0
# Name: Size, dtype: float64

# %%
rent_df = rent_df.fillna(rent_df.median(numeric_only = True))

# %%
rent_df.isna().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   float64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   float64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 445.1+ KB

# %%
rent_df['Floor'].value_counts().head()
# Out:
# Floor
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
# Name: count, dtype: int64

# %%
rent_df['Area Type'].value_counts()
# Out:
# Area Type
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: count, dtype: int64

# %%
rent_df['Area Locality'].value_counts().head()
# Out:
# Area Locality
# Bandra West        37
# Gachibowli         29
# Electronic City    24
# Velachery          22
# Miyapur, NH 9      22
# Name: count, dtype: int64

# %%
rent_df['Area Type'].nunique()
# Out:
# 3

# %%
for i in ['Floor', 'Area Type', 'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred', 'Point of Contact'] :
    print(i, rent_df[i].nunique())
# Out:
# Floor 480
# Area Type 3
# Area Locality 2235
# City 6
# Furnishing Status 3
# Tenant Preferred 3
# Point of Contact 3

# %%
rent_df.drop(['Floor', 'Area Locality', 'Tenant Preferred', 'Point of Contact', 'Posted On'],
             axis = 1, inplace =True)

# %%
rent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BHK                4746 non-null   float64
#  1   Rent               4746 non-null   int64
#  2   Size               4746 non-null   float64
#  3   Area Type          4746 non-null   object
#  4   City               4746 non-null   object
#  5   Furnishing Status  4746 non-null   object
#  6   Bathroom           4746 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 259.7+ KB

# %%
rent_df = pd.get_dummies(rent_df, columns = ['Area Type', 'City', 'Furnishing Status'])

rent_df.head()
# Out:
#    BHK   Rent    Size  Bathroom  Area Type_Built Area  Area Type_Carpet Area  \
# 0  2.0  10000  1100.0         2                 False                  False
# 1  2.0  20000   800.0         1                 False                  False
# 2  2.0  17000  1000.0         1                 False                  False
# 3  2.0  10000   800.0         1                 False                  False
# 4  2.0   7500   850.0         1                 False                   True
#
#    Area Type_Super Area  City_Bangalore  City_Chennai  City_Delhi  \
# 0                  True           False         False       False
# 1                  True           False         False       False
# 2                  True           False         False       False
# 3                  True           False         False       False
# 4                 False           False         False       False
#
#    City_Hyderabad  City_Kolkata  City_Mumbai  Furnishing Status_Furnished  \
# ...

# %%
x = rent_df.drop('Rent', axis = 1)
y = rent_df['Rent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 2024)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3796, 15), (950, 15), (3796,), (950,))

# %% [markdown]
# # **2.선형 회귀(Linear Regression)**
#
# * 데이터를 통해 데이터를 가장 잘 설명 할 수 있는 직선으로 데이터를 분석하는 방법
#     * 단순 선형 회귀 분석(단일 독립변수를 이용)
#     * 다중 선형 회귀 분석(다중 독립 변수를 이용)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred = lr.predict(X_test)

# %% [markdown]
# # **3. 평가 지표 만들기**

# %% [markdown]
# ### 3-1. MSE(Mean Squared Error)
#
# * 예측값과 실제값의 차이에 대한 제곱에 대해 평균을 낸 값
# * ${(\frac{1}{n})\sum_{i=1}^{n}(y_{i} - x_{i})^{2}}$

# %%
p = np.array([3, 4, 5]) # 예측 값
act = np.array([1, 2, 3]) # 실제 값

# %%
def my_mse(pred, actual) :

    return((pred - actual) ** 2).mean()

# %%
my_mse(p, act)
# Out:
# 4.0

# %% [markdown]
# ### 3-2. MAE(Mean Absoulte Error)
#
# * 예측값과 실제값의 차이에 대한 절대값에 대해 평균을 낸 값
# * $(\frac{1}{n})\sum_{i=1}^{n}\left | y_{i} - x_{i} \right |$

# %%
def my_mae(pred, actual) :

    return np.abs(pred - actual).mean()

# %%
my_mae(p, act)
# Out:
# 2.0

# %% [markdown]
# ### 3-3.RMSE(Root Mean Squared Error)
#
# * 예측값과 실제값의 차이에 대한 제곱에 대해 평균을 낸 후 루트를 씌운 값
# * $\sqrt{(\frac{1}{n})\sum_{i=1}^{n}(y_{i} - x_{i})^{2}}$

# %%
def my_rmse(pred, actual) :

    return np.sqrt(my_mse(pred, actual))

# %%
my_rmse(p, act)
# Out:
# 2.0

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(p, act)
# Out:
# 2.0

# %%
mean_squared_error(p, act)
# Out:
# 4.0

# %%
mean_squared_error(p, act, squared = False) # RMSE
# Out:
# 2.0

# %% [markdown]
# ### 3-4. 평가 지표 적용하기

# %%
mean_squared_error(y_test, pred)
# Out:
# 1426204740.330996

# %%
mean_absolute_error(y_test, pred)
# Out:
# 21997.237341647397

# %%
mean_squared_error(y_test, pred, squared = False)
# Out:
# 37765.125980605386

# %%
X_train.drop(1837, inplace = True)
y_train.drop(1837, inplace = True)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred2 = lr2.predict(X_test)

# %%
mean_squared_error(y_test, pred2, squared = False)
# Out:
# 37731.275512059074

# %%
# pred rmse : 37765.125980605386 (1837 삭제전)
# pred2 rmse : 37731.275512059074 (1837 삭제후)

37765.125980605386 - 37731.275512059074 # 오차가 줄었음 -> 성능이 조금 개선 되었다
# Out:
# 33.850468546312186
