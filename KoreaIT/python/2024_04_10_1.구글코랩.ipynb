# %% [markdown]
# # **1. 코랩의 성능**

# %% [markdown]
# ### 1-1. OS 환경

# %%
# !cat /etc/issue.net

# ! 가 들어가면 리눅스 명령어
# Out:
# Ubuntu 22.04.3 LTS

# %% [markdown]
# ### 1-2. python 버전

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# # **2. 셀의 종류**
#
# * 코드: 파이썬 코드 및 리눅스 명령어를 실행할 수 있는 셀
# * 텍스트 : 설명을 달거나 문구 등을 적기 위한 텍스트 전용 셀(마크다운)

# %% [markdown]
# ### 2-1. 셀의 삽입 방법
#
# * 상단의 "+ 코드", "+ 텍스트" 버튼을 눌러 삽입
# * 코드셀을 위에 삽입: ctrl + m a
# * 코드셀을 아래에 삽입: ctrl + m b

# %% [markdown]
# ### 2-2. 셀을 변경하는 방법
#
# * 코드셀을 텍스트 셀로 변경: ctrl + m m
# * 텍스트 셀을 코드셀로 변경: ctrl + m y

# %% [markdown]
# ### 2-3. 셀을 삭제하는 방법
#
# * 우측의 휴지통 아이콘을 클릭하여 삭제
# * ctrl + m d

# %% [markdown]
# ### 2-4. 실행을 취소하는 방법
#
# * 셀을 이전 상태로 복구: ctrl + m z

# %% [markdown]
# # **3. 셀의 실행**
#
# * ctrl + enter: 해당 셀을 실행하고 커서는 해당 셀에 남음
# * shift + enter : 해당 셀을 실행하고 다음 셀로 넘어감
# * alt + enter : 해당 셀을 실행하고 커서는 다음 셀을 삽입 후 넘어감

# %%
print('Hello, World!')
# Out:
# Hello, World!
