# %% [markdown]
# # **1. 모듈**
#
# 파이썬에서 모듈을 만들려면 간단히 .py 확장자를 가진 파일에 코드를 작성하면 됩니다.<br> 모듈은 단순한 함수 뿐만 아니라 변수, 클래스 등도 포함할 수 있으며, 다른 스크립트에서 import 구문을 사용하여 가져올 수 있습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import math_tools_2024_05_13

# %%
# 모듈 내의 변수 사용

print(math_tools_2024_05_13)
# Out:
# <module 'math_tools_2024_05_13' from '/content/drive/MyDrive/Korea it 아카데미/Python/module/math_tools_2024_05_13.py'>

# %%
# 모듈 내의 함수 사용

print(math_tools_2024_05_13.add(5, 3))
print(math_tools_2024_05_13.subtract(5, 3))
# Out:
# 8
# 2

# %%
# 모듈 내의 클래스 사용

circle = math_tools_2024_05_13.Circle(5)

print(circle.area())
# Out:
# 78.5398

# %%
# 필요한 필드, 클래스만 가져오기

from math_tools_2024_05_13 import pi, Circle

print(pi)

circle = Circle(7)
print(circle.area())
# Out:
# 3.141592
# 153.93800800000002

# %%
# 별명으로 모듈 사용하기

import math_tools_2024_05_13 as mt

print(mt.pi)
print(mt.add(5, 3))
print(mt.subtract(4, 2))

circle = mt.Circle(5)
print(circle.area())
# Out:
# 3.141592
# 8
# 2
# 78.5398

# %%
# 별명으로 필요한 필드, 클래스 가져오기

from math_tools_2024_05_13 import pi as p, Circle as c

print(p)

circle = c(7)
print(circle.area())
# Out:
# 3.141592
# 153.93800800000002

# %% [markdown]
# # **2. 구글 드라이브를 활용하여 모듈 사용하기**

# %%
path = '/content/drive/MyDrive/Korea it 아카데미/Python/module'

# %%
import sys

# %%
sys.path.append(path)

# %%
from math_tools_2024_05_13 import pi, Circle

print(pi)

circle = Circle(7)
print(circle.area())
# Out:
# 3.141592
# 153.93800800000002

# %% [markdown]
# # **3. 패키지**
#
# 파이썬에서 패키지는 모듈들을 포함하고 있는 디렉터리입니다.<br> 모듈은 파이썬 코드를 담고 있는 파일이며, 여러 모듈을 논리적으로 그룹화하려는 경우 패키지를 사용합니다.<br> 패키지를 사용하면 관련된 기능들을 함께 묶어서 코드를 더욱 체계적으로 관리할 수 있습니다.

# %%
from shapes import circle, rectangle

# %%
print(rectangle.area(4, 6))
print(rectangle.perimeter(4, 6))
# Out:
# 24
# 20

# %%
from shapes.circle import area as circle_area
from shapes.rectangle import area as rectangle_area

print(circle_area(5))
print(rectangle_area(4, 6))
# Out:
# 78.5398
# 24

# %%
from shapes import circle, rectangle

print(rectangle.area(4, 6))
print(rectangle.perimeter(4, 6))
# Out:
# 24
# 20
