# %% [markdown]
# # **1. 변수**
#
# * 변수는 프로그래밍에서 데이터를 저장하고 관리하는 데 사용되는 중요한 개념입니다.
# * 변수는 이름이 붙은 메모리 공간으로, 값을 저장하거나 참조할 때 사용됩니다.

# %%
name = '홍길동'
age = 20

print(name, age)

'''
'홍길동' 이라는 값이 메모리에 올라가고 name 이라는 메모리 공간을 생성
name 메모리 공간은 '홍길동' 의 메모리 주소를 가지게 된다.
'''
# Out:
# 홍길동 20

# %%
print(name)

name = 'banana'
print(name)

'''
변수를 다시 지정함에 따라 메모리 공간 name의 메모리 주소가 변경될 수가 있다.
'''
# Out:
# 홍길동
# banana

# %% [markdown]
# # **2. 변수의 이름 작성하는 방법**
#
# * 파이썬 변수는 대소문자를 구분하며, 예약어 (예: if, while, for 등)는 변수 이름으로 사용할 수 없습니다.
# * 변수 이름은 알파벳으로 시작해야 하며, 숫자나 특수문자는 첫 글자로 올 수 없습니다.
# * 변수 이름은 의미있고 알아보기 쉬운 이름으로 지정하는 것이 좋습니다.

# %%
name = '사과'
Name = '바나나'
NaMe = '오렌지'

print(name)
print(Name)
print(NaMe)
# Out:
# 사과
# 바나나
# 오렌지

# %% [markdown]
# # **3. 변수의 자료형**
#
# * 파이썬은 동적 타이핑(dynamic typing) 언어로, 변수의 타입을 선언할 필요 없이 값을 할당할 때 자동으로 타입을 추론합니다.
# * 이는 프로그래머가 변수의 타입을 직접 명시할 필요 없이 더 유연하게 코드를 작성할 수 있는 장점을 제공합니다.
# * 그렇지만 이로 인해 잘못된 타입의 값이 변수에 할당되는 상황도 발생할 수 있습니다.

# %% [markdown]
# 1. 기본 데이터 타입: 파이썬이 제공하는 기본적인 데이터 타입입니다.
#
# * 정수 타입 (int): 정수 값을 나타냅니다. 예를 들어, x = 5와 같이 할당될 수 있습니다.
# * 부동소수점 타입 (float): 실수 값을 나타냅니다. 예를 들어, pi = 3.14와 같이 할당될 수 있습니다.
# * 문자열 타입 (str): 문자나 문자열을 나타냅니다. 예를 들어, name = "김사과"와 같이 할당될 수 있습니다.
# * 부울 타입 (bool): 참(True) 또는 거짓(False) 값을 나타냅니다. 예를 들어, is_love = True와 같이 할당될 수 있습니다.
#
#
#
# 2. 컬렉션 데이터 타입: 여러 개의 값을 묶어서 관리하는 데 사용되며, 더 복잡한 데이터 구조를 나타냅니다.
# * 리스트 (list): 여러 값을 순차적으로 저장하는 자료구조입니다. [1, 2, 3]와 같이 할당될 수 있습니다.
# * 튜플 (tuple): 리스트와 유사하지만 변경할 수 없는(immutable) 자료구조입니다. (1, 2, 3)와 같이 할당될 수 있습니다.
# * 딕셔너리 (dict): 키(key)와 값(value)을 쌍으로 저장하는 자료구조입니다. {"name": "김사과", "age": 20}와 같이 할당될 수 있습니다.
# * 집합 (set): 중복되지 않는 값을 저장하는 자료구조입니다. {1, 2, 3}와 같이 할당될 수 있습니다.

# %%
name = '사과'
print(type(name))

age = 20
print(type(age))

weight = 50.5
print(type(weight))

is_lover = True
print(type(is_lover))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # **4. 변수의 삭제**
#
# * 변수를 삭제하기 위해 del 문을 사용할 수 있습니다.
# * del 문은 지정된 변수를 제거하고 해당 메모리 공간을 해제합니다.
# * 변수가 삭제되면 해당 이름으로 변수에 더 이상 접근할 수 없습니다.

# %%
print(is_lover)
# Out:
# True

# %%
del is_lover

print(is_lover)

'''
del을 사용함으로서 is_over 라는 변수가 삭제됩니다.
그렇게 되면 남은 변수가 없는 메모리 값들은 한번에 제거된다.
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-98c46554fcf7> in <cell line: 3>()
#       1 del is_lover
#       2
# ----> 3 print(is_lover)
#
# NameError: name 'is_lover' is not defined

# %%
'''
name1 와 name2 는 모두 '사과'라는 메모리 값의 주소를 갖는다.
따라서 name1이 제거 된다고 하더라도 메모리 값을 가지고 있는 name2 가 있기에
'사과'라는 메모리 값은 사라지지 않는다.
'''

name1 = '사과'
name2 = name1

del name1

print(name2)
# Out:
# 사과
